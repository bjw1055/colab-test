# %%
test

# %%
# !git commit -m 'colab-git-test'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Test_code.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
pwd
# Out:
# '/content'

# %%
cd /content/drive/MyDrive/Colab Notebooks/Github/colab-test/colab-test
# Out:
# /content/drive/MyDrive/Colab Notebooks/Github/colab-test/colab-test

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Github/colab-test/colab-test'

# %%
# !git commit -m 'colab_git_clone_test'
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@0521d79140d1.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "bjw1055@gmail.com"
# !git config --global user.name "bjw1055"

# %%
# !git add Test_code.ipynb
# !git commint -m 'colab-git-test'
